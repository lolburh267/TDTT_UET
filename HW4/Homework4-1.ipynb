# %% [markdown]
# WA16

# %%
for i in range(3,100,3):
    print(i)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99

# %% [markdown]
# W4A17

# %%
a =int(input())
for i in range(1,11):
    print(a,"x",i,"=",a*i)
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# W4A18

# %%
a,b=map(int,input().split())
k=a if a>b else b
for i in range(1,k+1):
    if a%i==0 and b%i==0:
        print(i)
# Out:
# 1
# 2
# 4
